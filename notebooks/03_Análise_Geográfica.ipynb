# %% [markdown]
# <a href="https://colab.research.google.com/github/JohnDiognes/analise-perfil-eleitor-vila-velha/blob/main/notebooks/03_An%C3%A1lise_Geogr%C3%A1fica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 03 — Análise Geográfica (Mapas por Bairro)
# Perfil do Eleitor — Município de Vila Velha – ES
# Autor: *Diognes Gonçalves dos Santos*
# Projeto: Portfólio Profissional — Área de Dados
#
# ---
#
# ## 🎯 Objetivo do Notebook
#
# Este notebook tem como objetivo:
#
# - Integrar as bases de eleitores com a malha geográfica dos bairros de Vila Velha.
# - Criar mapas temáticos (*choropleth maps*) com **Folium**.
# - Visualizar distribuições por:
#   - Quantidade de eleitores por bairro
#   - Perfil etário
#   - Distribuição por gênero
# - Preparar camadas geográficas reutilizáveis para dashboards (Power BI, Tableau etc.)
#
# ---

# %% [markdown]
# 1. Importar bibliotecas

# %%
import pandas as pd
import geopandas as gpd
import folium
from folium.plugins import HeatMap
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Carregar dados
#
# - `base_vila_velha.csv`: dataset consolidado no Notebook 02
# - `BairroXRegiao.csv`: tabela auxiliar
# - `shapefile dos bairros`: será necessário para os mapas

# %% [markdown]
# Carregar base de eleitores

# %%
# !rm -rf analise-perfil-eleitor-vila-velha
# !git clone https://github.com/JohnDiognes/analise-perfil-eleitor-vila-velha.git
# Out:
# Cloning into 'analise-perfil-eleitor-vila-velha'...
# remote: Enumerating objects: 172, done.
# remote: Counting objects: 100% (172/172), done.
# remote: Compressing objects: 100% (154/154), done.
# remote: Total 172 (delta 76), reused 50 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (172/172), 11.27 MiB | 26.47 MiB/s, done.
# Resolving deltas: 100% (76/76), done.
# Filtering content: 100% (7/7), 915.57 MiB | 30.88 MiB/s, done.
# Encountered 2 file(s) that should have been pointers, but weren't:
# 	Documents/Projeto_perfil_eleitor_2024_ES/BairroXRegiao.csv
# 	Documents/Projeto_perfil_eleitor_2024_ES/Local_votacao_Vila_Velha.csv

# %%
sns.set(style="whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# -----------------------------
# Clonar o repositório (somente se não existir)
# -----------------------------
repo_nome = "analise-perfil-eleitor-vila-velha"

if not os.path.exists(repo_nome):
    # !git clone https://github.com/JohnDiognes/analise-perfil-eleitor-vila-velha.git

# Caminho da base
caminho_base = f"{repo_nome}/dados/base_vila_velha.csv"

# -----------------------------
# Carregar a base
# -----------------------------
try:
    df_vv = pd.read_csv(caminho_base, encoding="utf-8")
except:
    df_vv = pd.read_csv(caminho_base, encoding="latin1")

df_vv.head()
# Out:
# Cloning into 'analise-perfil-eleitor-vila-velha'...
# remote: Enumerating objects: 129, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (111/111), done.
# remote: Total 129 (delta 51), reused 51 (delta 9), pack-reused 0 (from 0)
# Receiving objects: 100% (129/129), 11.20 MiB | 26.18 MiB/s, done.
# Resolving deltas: 100% (51/51), done.
# Filtering content: 100% (7/7), 915.57 MiB | 67.04 MiB/s, done.
# Encountered 2 file(s) that should have been pointers, but weren't:
# 	Documents/Projeto_perfil_eleitor_2024_ES/BairroXRegiao.csv
# 	Documents/Projeto_perfil_eleitor_2024_ES/Local_votacao_Vila_Velha.csv
#     ano  uf   municipio  cod_municipio  zona  secao  cod_genero     genero  \
# 0  2024  ES  VILA VELHA          57037    32    266           4   FEMININO
# 1  2024  ES  VILA VELHA          57037    32    951           4   FEMININO
# 2  2024  ES  VILA VELHA          57037    32    936           4   FEMININO
# 3  2024  ES  VILA VELHA          57037    57    155           4   FEMININO
# 4  2024  ES  VILA VELHA          57037    57     48           2  MASCULINO
#
#    cod_estado_civil estado_civil  ...  interprete de libras        bairro  \
# 0                 3       CASADO  ...         NÃO INFORMADO          PAUL
# 1                 3       CASADO  ...         NÃO INFORMADO        ITAPOÃ
# 2                 3       CASADO  ...         NÃO INFORMADO        ITAPOÃ
# 3                 1     SOLTEIRO  ...         NÃO INFORMADO  SÃO TORQUATO
# 4                 3       CASADO  ...         NÃO INFORMADO    COBILÂNDIA
#
#    regiao cod_local_votacao                              local_votacao_nome  \
# 0       3              1430                             UMEF GRACIANO NEVES
# 1       1              2070                                    COLÉGIO CEIC
# 2       1              2070                                    COLÉGIO CEIC
# 3       4              1201               UMEF JUIZ JAIRO DE MATTOS PEREIRA
# 4       4              1341  CEEFMTI PASTOR OLIVEIRA DE ARAUJO- ESCOLA VIVA
#
#                local_votacao_endereco  quant_eleitores quant_biometria  \
# 0                R. COUTO AGUIRRE, 49                1               1
# 1    RUA JAIME DUARTE NASCIMENTO, 617                1               1
# 2    RUA JAIME DUARTE NASCIMENTO, 617                1               1
# 3  RUA PASTOR AMBROSINO BARBOSA, S/ N                1               1
# 4           AVENIDA OTÁVIO BORIN, S/N                1               1
#
#    quan_deficiencia quant_nome_social
# 0                 0                 0
# 1                 0                 0
# 2                 1                 0
# 3                 0                 0
# 4                 0                 0
#
# [5 rows x 31 columns]

# %% [markdown]
# Carregar tabela de bairros e regiões

# %%
try:
    bairros = pd.read_csv(f"{repo_nome}/Documents/Projeto_perfil_eleitor_2024_ES/BairroXRegiao.csv", encoding="utf-8")
except UnicodeDecodeError:
    bairros = pd.read_csv(f"{repo_nome}/Documents/Projeto_perfil_eleitor_2024_ES/BairroXRegiao.csv", encoding="latin1")
bairros.head()
# Out:
#    num_regiao              nom_bairro
# 0           1             Boa Vista I
# 1           1            Boa Vista II
# 2           1                  Centro
# 3           1  Coqueiral de Itaparica
# 4           1       Cristóvão Colombo

# %% [markdown]
# Importar shapefile de Vila Velha
#
# colocar o shapefile na pasta dados/geodata/ como:

# %%
mapa = gpd.read_file(f"{repo_nome}/dados/geodata/bairros_vila_velha.shp")
mapa.head()
# Out:
#                    BAIRRO CODBAIRRO  DocID  OwnerID CadType  Level  Color  \
# 0                JABURUNA        18    NaN      NaN    None    NaN    NaN
# 1            SANTA MÔNICA       161    NaN      NaN    None    NaN    NaN
# 2   RESIDENCIAL COQUEIRAL        67    NaN      NaN    None    NaN    NaN
# 3                  SOTECO        66    NaN      NaN    None    NaN    NaN
# 4  COQUEIRAL DE ITAPARICA        12    NaN      NaN    None    NaN    NaN
#
#    LineWt Layer Handle  ... TxtAttach TxtDir LnSpace  SpaceFact  DocName  \
# 0     NaN  None   None  ...       NaN    NaN     NaN        NaN     None
# 1     NaN  None   None  ...       NaN    NaN     NaN        NaN     None
# 2     NaN  None   None  ...       NaN    NaN     NaN        NaN     None
# 3     NaN  None   None  ...       NaN    NaN     NaN        NaN     None
# 4     NaN  None   None  ...       NaN    NaN     NaN        NaN     None
#
#    DocPath  DocType DocVer  XDList  \
# 0     None     None   None    None
# 1     None     None   None    None
# 2     None     None   None    None
# 3     None     None   None    None
# 4     None     None   None    None
#
#                                             geometry
# 0  POLYGON ((363434.724 7751165.889, 363432.91 77...
# 1  POLYGON ((363761.592 7748055.804, 363904.666 7...
# 2  POLYGON ((364130.917 7748346.266, 364118.952 7...
# 3  POLYGON ((363402.978 7748499.386, 363415.998 7...
# 4  POLYGON ((363381.341 7747424.748, 363449.897 7...
#
# [5 rows x 67 columns]

# %% [markdown]
# 🧩 3. Preparar base geográfica
# Normalizar nomes de bairros

# %%
df_vv['bairro'] = df_vv['bairro'].str.upper().str.strip()
mapa['BAIRRO'] = mapa['BAIRRO'].str.upper().str.strip()

# %% [markdown]
# Cruzar base de eleitores + mapa

# %%
df_bairro = df_vv.groupby('bairro').size().reset_index(name='qtd_eleitores')
df_geo = mapa.merge(df_bairro, left_on='BAIRRO', right_on='bairro', how='left')
df_geo['qtd_eleitores'] = df_geo['qtd_eleitores'].fillna(0)
df_geo.head()
# Out:
#                    BAIRRO CODBAIRRO  DocID  OwnerID CadType  Level  Color  \
# 0                JABURUNA        18    NaN      NaN    None    NaN    NaN
# 1            SANTA MÔNICA       161    NaN      NaN    None    NaN    NaN
# 2   RESIDENCIAL COQUEIRAL        67    NaN      NaN    None    NaN    NaN
# 3                  SOTECO        66    NaN      NaN    None    NaN    NaN
# 4  COQUEIRAL DE ITAPARICA        12    NaN      NaN    None    NaN    NaN
#
#    LineWt Layer Handle  ... LnSpace SpaceFact DocName  DocPath  DocType  \
# 0     NaN  None   None  ...     NaN       NaN    None     None     None
# 1     NaN  None   None  ...     NaN       NaN    None     None     None
# 2     NaN  None   None  ...     NaN       NaN    None     None     None
# 3     NaN  None   None  ...     NaN       NaN    None     None     None
# 4     NaN  None   None  ...     NaN       NaN    None     None     None
#
#    DocVer  XDList                                           geometry  \
# 0    None    None  POLYGON ((363434.724 7751165.889, 363432.91 77...
# 1    None    None  POLYGON ((363761.592 7748055.804, 363904.666 7...
# 2    None    None  POLYGON ((364130.917 7748346.266, 364118.952 7...
# 3    None    None  POLYGON ((363402.978 7748499.386, 363415.998 7...
# 4    None    None  POLYGON ((363381.341 7747424.748, 363449.897 7...
#
#                    bairro  qtd_eleitores
# 0                JABURUNA         1617.0
# 1            SANTA MÔNICA         2975.0
# 2                     NaN            0.0
# 3                  SOTECO         6451.0
# 4  COQUEIRAL DE ITAPARICA        15066.0
#
# [5 rows x 69 columns]

# %% [markdown]
# 4. Mapa — Eleitores por Bairro

# %%
m = folium.Map(location=[-20.3477, -40.2949], zoom_start=12)

folium.Choropleth(
    geo_data=df_geo,
    data=df_geo,
    columns=["BAIRRO", "qtd_eleitores"],
    key_on="feature.properties.BAIRRO",
    fill_color="YlOrRd",
    fill_opacity=0.7,
    line_opacity=0.3,
    legend_name="Quantidade de Eleitores por Bairro"
).add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_930d0e6fcd56d668fd787891b0c66476 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_930d0e6fcd56d668fd787891b0c66476&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_930d0e6fcd56d668fd787891b0c66476 = L.map(
#                 &quot;map_930d0e6fcd56d668fd787891b0c66476&quot;,
#                 {
#                     center: [-20.3477, -40.2949],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c31252ebdb9fde8e0173ae10c2336f54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c31252ebdb9fde8e0173ae10c2336f54.addTo(map_930d0e6fcd56d668fd787891b0c66476);
#
#
#             var choropleth_aa2325e0b0a766e7ca3f8cd8a4a521be = L.featureGroup(
#                 {
# }
#             );
#
#
#         function geo_json_0082d39090101c62359dbd0881361781_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;2&quot;: case &quot;5&quot;: case &quot;6&quot;: case &quot;7&quot;: case &quot;9&quot;: case &quot;10&quot;: case &quot;11&quot;: case &quot;15&quot;: case &quot;16&quot;: case &quot;17&quot;: case &quot;18&quot;: case &quot;19&quot;: case &quot;21&quot;: case &quot;22&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;25&quot;: case &quot;27&quot;: case &quot;28&quot;: case &quot;29&quot;: case &quot;30&quot;: case &quot;31&quot;: case &quot;33&quot;: case &quot;34&quot;: case &quot;35&quot;: case &quot;36&quot;: case &quot;37&quot;: case &quot;38&quot;: case &quot;39&quot;: case &quot;42&quot;: case &quot;43&quot;: case &quot;44&quot;: case &quot;45&quot;: case &quot;46&quot;: case &quot;48&quot;: case &quot;52&quot;: case &quot;53&quot;: case &quot;54&quot;: case &quot;55&quot;: case &quot;56&quot;: case &quot;59&quot;: case &quot;60&quot;: case &quot;61&quot;: case &quot;66&quot;: case &quot;67&quot;: case &quot;71&quot;: case &quot;72&quot;: case &quot;73&quot;: case &quot;74&quot;: case &quot;75&quot;: case &quot;76&quot;: case &quot;77&quot;: case &quot;78&quot;: case &quot;79&quot;: case &quot;80&quot;: case &quot;81&quot;: case &quot;82&quot;: case &quot;83&quot;: case &quot;85&quot;: case &quot;87&quot;: case &quot;88&quot;: case &quot;90&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffb2&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;8&quot;: case &quot;20&quot;: case &quot;26&quot;: case &quot;40&quot;: case &quot;41&quot;: case &quot;47&quot;: case &quot;49&quot;: case &quot;57&quot;: case &quot;58&quot;: case &quot;62&quot;: case &quot;63&quot;: case &quot;64&quot;: case &quot;68&quot;: case &quot;69&quot;: case &quot;70&quot;: case &quot;84&quot;: case &quot;86&quot;: case &quot;89&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fed976&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;3&quot;: case &quot;32&quot;: case &quot;50&quot;: case &quot;51&quot;: case &quot;65&quot;: case &quot;91&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#feb24c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;12&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#f03b20&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 case &quot;13&quot;: case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#fd8d3c&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#bd0026&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.3, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0082d39090101c62359dbd0881361781_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_0082d39090101c62359dbd0881361781 = L.geoJson(null, {
#                 onEachFeature: geo_json_0082d39090101c62359dbd0881361781_onEachFeature,
#
#                 style: geo_json_0082d3909

# %% [markdown]
# 5. Mapa — Percentual de Mulheres por Bairro

# %%
df_genero = df.groupby(["bairro", "genero"]).size().unstack(fill_value=0)
df_genero["pct_mulheres"] = df_genero["FEMININO"] / df_genero.sum(axis=1)

df_geo = df_geo.merge(df_genero["pct_mulheres"], on="bairro", how="left")

# %%
m2 = folium.Map(location=[-20.3477, -40.2949], zoom_start=12)

folium.Choropleth(
    geo_data=df_geo,
    data=df_geo,
    columns=["bairro", "pct_mulheres"],
    key_on="feature.properties.bairro",
    fill_color="PuRd",
    fill_opacity=0.7,
    line_opacity=0.3,
    legend_name="Percentual de Mulheres"
).add_to(m2)

m2

# %% [markdown]
# 6. Mapa — Faixas Etárias

# %%
Criar indicador numérico de idade

# %%
df['idade'] = 2024 - df['ano_nascimento']

# %%
faixas = pd.cut(
    df['idade'],
    bins=[16, 24, 34, 44, 59, 120],
    labels=["16–24", "25–34", "35–44", "45–59", "60+"]
)

df['faixa_etaria'] = faixas

# %% [markdown]
# Distribuição por bairro

# %%
df_idade = df.groupby(["bairro", "faixa_etaria"]).size().reset_index(name="total")
df_idade.head()

# %% [markdown]
# Exemplo: mapa da faixa etária “60+”

# %%
idosos = df_idade[df_idade["faixa_etaria"] == "60+"]

df_geo_idosos = mapa.merge(idosos, on="bairro", how="left")
df_geo_idosos["total"] = df_geo_idosos["total"].fillna(0)

# %%
m3 = folium.Map(location=[-20.3477, -40.2949], zoom_start=12)

folium.Choropleth(
    geo_data=df_geo_idosos,
    data=df_geo_idosos,
    columns=["bairro", "total"],
    key_on="feature.properties.bairro",
    fill_color="BuPu",
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Quantidade de Eleitores 60+ por Bairro"
).add_to(m3)

m3

# %% [markdown]
# 7. Heatmap — Concentração de Eleitores

# %%
df_latlon = df.dropna(subset=["latitude", "longitude"])

# %%
m4 = folium.Map(location=[-20.3477, -40.2949], zoom_start=12)

HeatMap(
    data=df_latlon[['latitude', 'longitude']].values,
    radius=12,
    blur=15
).add_to(m4)

m4

# %% [markdown]
# 📌 8. Conclusões do Notebook
#
# O cruzamento das bases permitiu gerar mapas temáticos por bairro.
#
# Identificamos regiões com maior densidade de eleitores.
#
# Foram criados indicadores geográficos que podem ser exportados para dashboards.
#
# Os mapas interativos permitem explorar rapidamente padrões demográficos no município.

# %% [markdown]
# 9. Exportar base geográfica para uso externo (Power BI, Tableau)

# %%
df_geo.to_file("../dados/geodata/saida_bairros.geojson", driver="GeoJSON")
